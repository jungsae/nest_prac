// %%
// async 학습및 테스트
async function fetchUser() {
    const response = await fetch('http://localhost:8000/users/everything');
    const data = await response.json();
    console.log(data);
    return data;
}
const user = await fetchUser();
console.log(user[0].role);
// Out:
// [
//   {
//     id: 6,
//     name: "jay",
//     email: "112@test.com",
//     role: "USER",
//     createdAt: "2026-01-09T05:33:49.858Z",
//     updatedAt: "2026-01-09T05:39:33.204Z",
//     deletedAt: null
//   }
// ]
// USER
